# %%
#import data science packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm
from sklearn.metrics import accuracy_score
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV

# %%
#Read csv into encoded_df
encoded_df = pd.read_csv("GWAS_analysis_OHE.csv")
encoded_df.head()
# Out:
#           Unnamed: 0  Gender  rs3769005_CC  rs3769005_CG  rs3769005_GG  \
# 0  6198863118_R01C01       0             0             0             1
# 1  8647968039_R01C02       0             0             0             1
# 2  6198863118_R02C01       0             0             0             1
# 3  6198863118_R03C01       1             0             1             0
# 4  8647968039_R02C02       0             0             0             1
#
#    imm_1_67459652_AA  imm_1_67459652_AG  imm_1_67459652_GG  imm_7_51057559_AA  \
# 0                  0                  1                  0                  0
# 1                  0                  1                  0                  0
# 2                  1                  0                  0                  0
# 3                  0                  0                  1                  0
# 4                  1                  0                  0                  0
#
#    imm_7_51057559_AG  ...  rs1375131_AA  rs1375131_AG  rs1375131_GG  \
# 0                  1  ...             1             0             0
# 1                  0  ...             1             0             0
# 2                  0  ...             1             0             0
# 3                  1  ...             0             0             1
# 4                  0  ...             1             0             0
#
#    rs2563397_AG  rs2563397_GG  1kg_1_241045805_AA  1kg_1_241045805_AG  \
# 0             0             1                   1                   0
# 1             0             1                   1                   0
# 2             0             1                   1                   0
# 3             1             0                   0                   1
# 4             0             1                   1                   0
#
#    rs34367277_AG  rs34367277_GG  Affectation
# 0              0              1            0
# 1              0              1            0
# 2              0              1            0
# 3              1              0            0
# 4              0              1            0
#
# [5 rows x 1059 columns]

# %%
#Reset index to patient id
encoded_df.rename(columns={"Unnamed: 0":"patient_ID"}, inplace=True)
encoded_df.set_index("patient_ID", inplace= True)
encoded_df.head()
# Out:
#                    Gender  rs3769005_CC  rs3769005_CG  rs3769005_GG  \
# patient_ID
# 6198863118_R01C01       0             0             0             1
# 8647968039_R01C02       0             0             0             1
# 6198863118_R02C01       0             0             0             1
# 6198863118_R03C01       1             0             1             0
# 8647968039_R02C02       0             0             0             1
#
#                    imm_1_67459652_AA  imm_1_67459652_AG  imm_1_67459652_GG  \
# patient_ID
# 6198863118_R01C01                  0                  1                  0
# 8647968039_R01C02                  0                  1                  0
# 6198863118_R02C01                  1                  0                  0
# 6198863118_R03C01                  0                  0                  1
# 8647968039_R02C02                  1                  0                  0
#
#                    imm_7_51057559_AA  imm_7_51057559_AG  imm_7_51057559_GG  \
# patient_ID
# 6198863118_R01C01                  0                  1                  0
# 8647968039_R01C02                  0                  0                  1
# 6198863118_R02C01                  0                  0                  1
# 6198863118_R03C01                  0                  1                  0
# 8647968039_R02C02                  0                  0                  1
#
#                    ...  rs1375131_AA  rs1375131_AG  rs1375131_GG  \
# patient_ID         ...
# 6198863118_R01C01  ...             1             0             0
# 8647968039_R01C02  ...             1             0             0
# 6198863118_R02C01  ...             1             0             0
# 6198863118_R03C01  ...             0             0             1
# 8647968039_R02C02  ...             1             0             0
#
#                    rs2563397_AG  rs2563397_GG  1kg_1_241045805_AA  \
# patient_ID
# 6198863118_R01C01             0             1                   1
# 8647968039_R01C02             0             1                   1
# 6198863118_R02C01             0             1                   1
# 6198863118_R03C01             1             0                   0
# 8647968039_R02C02             0             1                   1
#
#                    1kg_1_241045805_AG  rs34367277_AG  rs34367277_GG  \
# patient_ID
# 6198863118_R01C01                   0              0              1
# 8647968039_R01C02                   0              0              1
# 6198863118_R02C01                   0              0              1
# 6198863118_R03C01                   1              1              0
# 8647968039_R02C02                   0              0              1
#
#                    Affectation
# patient_ID
# 6198863118_R01C01            0
# 8647968039_R01C02            0
# 6198863118_R02C01            0
# 6198863118_R03C01            0
# 8647968039_R02C02            0
#
# [5 rows x 1058 columns]

# %%
#shuffle the dataframe so that diseased and healthy patients are mixed up, not clumped together
encoded_df = shuffle(encoded_df)
sns.heatmap(encoded_df[["Gender", "Affectation"]])
# Out:
# <AxesSubplot:ylabel='patient_ID'>

# %%
#Generate X and y dataframes for model fitting
X_encoded = encoded_df.drop(["Affectation"], axis = 'columns')
y = encoded_df["Affectation"]
print(X_encoded.shape)
print(y.shape)
# Out:
# (2645, 1057)
# (2645,)

# %%
#Train test split the data
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.15, random_state=123, stratify = y)

#Print sizes of the split data
print(f"X_train : {X_train.shape}")
print(f"X_test : {X_test.shape}")
print(f"y_train : {y_train.shape}")
print(f"y_test : {y_test.shape}")
# Out:
# X_train : (2248, 1057)
# X_test : (397, 1057)
# y_train : (2248,)
# y_test : (397,)

# %%
#Check stratification ratios
y_train_strat = len(y_train[y_train == 0]) / len(y_train[y_train == 1])
y_test_strat = len(y_test[y_test == 0]) / len(y_test[y_test == 1])
print(f"y_train : {y_train.value_counts()}")
print('Ratio of 0:1 in y_train: %0.2f' % y_train_strat )
print(f"y_test : {y_test.value_counts()}")
print('Ratio of 0:1 in y_test: %0.2f' % y_test_strat)
# Out:
# y_train : 0    1391
# 1     857
# Name: Affectation, dtype: int64
# Ratio of 0:1 in y_train: 1.62
# y_test : 0    246
# 1    151
# Name: Affectation, dtype: int64
# Ratio of 0:1 in y_test: 1.63

# %%
#Define the model
model = MLPClassifier()

#For use in various print statements later
model_name = str(model).replace("()", "")

#CREATE LISTS OF HYPER_PARAMETERS TO TUNE

#Create list of solvers
solvers = ['lbfgs', 'sgd', 'adam']

#Create list of solvers
max_iter = [100, 250, 500, 750, 1000, 1250, 1500]

#Create list of alphas
alpha = [0.1   , 0.01  , 0.001 , 0.0001]

#Create list of hidden_layer_sizes
hidden_layer_sizes = [10 , 20]

#Convert the lists to a dictionary called grid
grid = dict(solver=solvers,alpha=alpha,max_iter=max_iter, hidden_layer_sizes=hidden_layer_sizes)

#Define the grid search
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=5, verbose=1)

#Fit the grid search
grid_result = grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 168 candidates, totalling 840 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed: 30.0min
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed: 67.1min
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed: 117.8min
# [Parallel(n_jobs=-1)]: Done 840 out of 840 | elapsed: 128.8min finished

# %%
# summarize results
print("Best: %0.2f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%0.2f (%0.2f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.81 using {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.75 (0.04) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.78 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'sgd'}
# 0.80 (0.03) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.81 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'adam'}
# 0.75 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'sgd'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'adam'}
# 0.77 (0.00) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'sgd'}
# 0.79 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.80 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.76 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'adam'}
# 0.78 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.80 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'sgd'}
# 0.79 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'sgd'}
# 0.77 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.1, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'adam'}
# 0.78 (0.03) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.75 (0.03) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'sgd'}
# 0.80 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.81 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.81 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.80 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'sgd'}
# 0.79 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.77 (0.03) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'adam'}
# 0.77 (0.03) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'sgd'}
# 0.77 (0.03) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.01) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.01, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'adam'}
# 0.78 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.75 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'adam'}
# 0.76 (0.03) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.81 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.81 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'sgd'}
# 0.76 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.03) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'sgd'}
# 0.79 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'adam'}
# 0.75 (0.03) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.75 (0.03) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.03) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'sgd'}
# 0.77 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'adam'}
# 0.75 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'sgd'}
# 0.79 (0.03) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'sgd'}
# 0.76 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'sgd'}
# 0.77 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'sgd'}
# 0.77 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.001, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.75 (0.04) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'sgd'}
# 0.79 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 100, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 250, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 500, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.81 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'adam'}
# 0.76 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.79 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'sgd'}
# 0.79 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1000, 'solver': 'adam'}
# 0.75 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'sgd'}
# 0.79 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1250, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 10, 'max_iter': 1500, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'lbfgs'}
# 0.76 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'sgd'}
# 0.79 (0.03) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 100, 'solver': 'adam'}
# 0.77 (0.03) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'sgd'}
# 0.77 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 250, 'solver': 'adam'}
# 0.77 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'lbfgs'}
# 0.79 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 500, 'solver': 'adam'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'lbfgs'}
# 0.80 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'sgd'}
# 0.78 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 750, 'solver': 'adam'}
# 0.77 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'lbfgs'}
# 0.80 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'sgd'}
# 0.77 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1000, 'solver': 'adam'}
# 0.78 (0.03) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'lbfgs'}
# 0.80 (0.01) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'sgd'}
# 0.77 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1250, 'solver': 'adam'}
# 0.76 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'lbfgs'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'sgd'}
# 0.78 (0.02) with: {'alpha': 0.0001, 'hidden_layer_sizes': 20, 'max_iter': 1500, 'solver': 'adam'}

# %%
# Best estimator object
print(f"Model = {grid_result.best_estimator_}")
print(f"Model parameters = {grid_result.best_params_}")

#Score on the test set
print("Accuracy score on the test set = %0.2f" % grid_result.score(X_test, y_test))

#Summarizing and storing the grid search in a dataframe
grid_search_results = pd.DataFrame(grid_result.cv_results_)
grid_search_results = grid_search_results.sort_values(by = 'mean_test_score', ascending = False )

#Output the info to a text file
filename = "model outputs/"+model_name+"_grid_search_results.txt"
f = open(filename, 'w')
print(f"Best performing model = {grid_result.best_estimator_} \n", file = f)
print("Accuracy score on the test set = %0.2f \n" % grid_result.score(X_test, y_test) , file = f)
print(f"Model parameters = {grid_result.best_params_} \n", file = f)
print(grid_search_results, file = f)
f.close()
# Out:
# Model = MLPClassifier(alpha=0.01, hidden_layer_sizes=10, max_iter=750, solver='sgd')
# Model parameters = {'alpha': 0.01, 'hidden_layer_sizes': 10, 'max_iter': 750, 'solver': 'sgd'}
# Accuracy score on the test set = 0.81

# %%
#calculate and plot receiver operating characteristics (ROC) and calculate area under the curve (AUC)
from sklearn.metrics import roc_curve, roc_auc_score
y_proba = grid_result.predict_proba(X_test)[:,1]
fprs, tprs, thresholds = roc_curve(y_test, y_proba)
roc_auc = roc_auc_score(y_test, y_proba)

fig = plt.figure()
plt.plot(fprs, tprs, color='darkorange',
         lw=2, label='AUC = %0.2f' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate (TPR)')
plt.title(f'ROC Curve for Disease Risk Prediction with {model_name}')
plt.legend(loc="best")

#save ROC curve to file
plt.savefig(f"model outputs/{model_name}_ROC_AUC_curve.pdf")
plt.show()

print('Area under curve (AUC) = %0.2f' % roc_auc)
print()
# Out:
# Area under curve (AUC) = 0.88

# %%
from sklearn.metrics import confusion_matrix

# get best model from grid search
best_model = grid_result.best_estimator_

#fit best model on training data
best_model_result = best_model.fit(X_train, y_train)

#predict y_values by using the .predict method
y_pred = best_model_result.predict(X_test)

#generate confusion matrix
my_confusion_matrix = confusion_matrix(y_test, y_pred)

#print confusion matrix
my_confusion_matrix
# Out:
# array([[211,  35],
#        [ 34, 117]], dtype=int64)

# %%
from sklearn.metrics import ConfusionMatrixDisplay as CMD

#plot confusion matrix
sns.heatmap(my_confusion_matrix, annot=True, fmt = '.0f') 
plt.xlabel("Predicted classes")
plt.ylabel("Actual classes")
plt.title(f'confusion matrix for {model_name}')

#save confusion matrix to file
plt.savefig(f"model outputs/{model_name}_confusion_matrix.pdf")
plt.show()

# %%
from sklearn.metrics import classification_report

report_initial = classification_report(y_test, y_pred)
print(report_initial)

#save classification report to file
filename = "model outputs/"+str(model_name)+"_classification_report.txt"
f = open(filename, 'w')
print(f"Classification report for {str(model_name)} \n", file=f)
print(report_initial, file = f)
f.close()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       246
#            1       0.77      0.77      0.77       151
#
#     accuracy                           0.83       397
#    macro avg       0.82      0.82      0.82       397
# weighted avg       0.83      0.83      0.83       397
